# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 200)

df = pd.read_csv("../datasets/raw/IndianWeatherRepository.csv")

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %% [markdown]
# # Shape Analysis

# %%
rows, cols = df.shape

print(f"Rows: {rows}")
print(f"Columns: {cols}")

# Insight
print("""
Insight:
The dataset contains 119,398 observations and 42 features,
making it sufficiently large for climate analytics,
machine learning, clustering, anomaly detection,
and risk prediction.
""")
# Out:
# Rows: 119398
# Columns: 42
#
# Insight:
# The dataset contains 119,398 observations and 42 features,
# making it sufficiently large for climate analytics,
# machine learning, clustering, anomaly detection,
# and risk prediction.

# %% [markdown]
# # Datatype Analysis

# %%
df.dtypes
# Out:
# country                             str
# location_name                       str
# region                              str
# latitude                        float64
# longitude                       float64
# timezone                            str
# last_updated_epoch                int64
# last_updated                        str
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                      str
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                      str
# pressure_mb                       int64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# ...

# %% [markdown]
# # Datatype Summary

# %%
datatype_summary = pd.DataFrame({
    "Column": df.columns,
    "Datatype": df.dtypes.values
})

datatype_summary
# Out:
#                           Column Datatype
# 0                        country      str
# 1                  location_name      str
# 2                         region      str
# 3                       latitude  float64
# 4                      longitude  float64
# 5                       timezone      str
# 6             last_updated_epoch    int64
# 7                   last_updated      str
# 8            temperature_celsius  float64
# 9         temperature_fahrenheit  float64
# 10                condition_text      str
# 11                      wind_mph  float64
# 12                      wind_kph  float64
# 13                   wind_degree    int64
# 14                wind_direction      str
# 15                   pressure_mb    int64
# 16                   pressure_in  float64
# 17                     precip_mm  float64
# 18                     precip_in  float64
# 19                      humidity    int64
# 20                         cloud    int64
# ...

# %% [markdown]
# # Missing Value Analysis

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# country                         0
# location_name                   0
# region                          0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# ...

# %% [markdown]
# # Missing Value Report

# %%
total_missing = missing_values.sum()

print("Total Missing Values:", total_missing)

# Insight
print("""
Insight:
No missing values were found.
No imputation is required.
Data quality is excellent.
""")
# Out:
# Total Missing Values: 0
#
# Insight:
# No missing values were found.
# No imputation is required.
# Data quality is excellent.

# %% [markdown]
# # Duplicate Analysis

# %%
duplicates = df.duplicated().sum()

print("Duplicate Records:", duplicates)

# Insight

print("""
Insight:
No duplicate observations exist.
Dataset integrity is maintained.
""")
# Out:
# Duplicate Records: 0
#
# Insight:
# No duplicate observations exist.
# Dataset integrity is maintained.

# %% [markdown]
# # Numerical vs Categorical Segmentation

# %%
numerical_columns = df.select_dtypes(
    include=["int64", "float64"]
).columns

categorical_columns = df.select_dtypes(
    include=["object", "string"]
).columns

print("Numerical Features:", len(numerical_columns))
print("Categorical Features:", len(categorical_columns))
# Out:
# Numerical Features: 30
# Categorical Features: 12

# %% [markdown]
# # Categorical Features

# %%
pd.DataFrame({
    "Categorical Features": categorical_columns
})
# Out:
#    Categorical Features
# 0               country
# 1         location_name
# 2                region
# 3              timezone
# 4          last_updated
# 5        condition_text
# 6        wind_direction
# 7               sunrise
# 8                sunset
# 9              moonrise
# 10              moonset
# 11           moon_phase

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()
# Out:
#             latitude      longitude  last_updated_epoch  temperature_celsius  temperature_fahrenheit       wind_mph       wind_kph    wind_degree    pressure_mb    pressure_in      precip_mm  \
# count  119398.000000  119398.000000        1.193980e+05        119398.000000            119398.00000  119398.000000  119398.000000  119398.000000  119398.000000  119398.000000  119398.000000
# mean       23.099620      80.246300        1.702939e+09            20.303723                68.54687       5.024552       8.090798     157.507044    1012.828196      29.908350       0.084331
# std         5.791228       5.763446        5.659113e+06             6.538599                11.76929       2.825159       4.538947     115.412587       4.926352       0.145307       0.608602
# min         7.170000      68.970000        1.693286e+09           -30.700000               -23.30000       2.200000       3.600000       1.000000     991.000000      29.280000       0.000000
# ...

# %% [markdown]
# # Categorical Statistics

# %%
df.describe(include=["object", "string"])
# Out:
#        country location_name         region      timezone    last_updated condition_text wind_direction  sunrise   sunset     moonrise     moonset      moon_phase
# count   119398        119398         119398        119398          119398         119398         119398   119398   119398       119398      119398          119398
# unique       1           552             33             3             877             50             16      202      215         1441        1441               8
# top      India         Nagar  Uttar Pradesh  Asia/Kolkata  04-02-24 23:00          Clear              N  6:17 AM  6:01 PM  No moonrise  No moonset  Waning Gibbous
# freq    119398           461          13293        118745             548          47978          12987     1597     1538         4389        3836           28478

# %% [markdown]
# # Unique Value Analysis

# %%
summary = pd.DataFrame({
    "Column": df.columns,
    "Datatype": df.dtypes.values,
    "Missing Values": df.isnull().sum().values,
    "Unique Values": df.nunique().values
})
summary
# Out:
#                           Column Datatype  Missing Values  Unique Values
# 0                        country      str               0              1
# 1                  location_name      str               0            552
# 2                         region      str               0             33
# 3                       latitude  float64               0            455
# 4                      longitude  float64               0            435
# 5                       timezone      str               0              3
# 6             last_updated_epoch    int64               0            432
# 7                   last_updated      str               0            877
# 8            temperature_celsius  float64               0            636
# 9         temperature_fahrenheit  float64               0           1056
# 10                condition_text      str               0             50
# 11                      wind_mph  float64               0            103
# ...

# %% [markdown]
# # Initial Climate Insights Report

# %%
print("""
CLIMATE INSIGHTS REPORT

1. Dataset contains 119,398 environmental observations.

2. Dataset covers 552 unique locations across India.

3. Dataset includes 33 regions/states.

4. Dataset contains weather, air quality,
   geographical, temporal, and astronomical data.

5. No missing values detected.

6. No duplicate records detected.

7. Air quality indicators available:
   - PM2.5
   - PM10
   - Carbon Monoxide
   - Ozone
   - Nitrogen Dioxide
   - Sulphur Dioxide

8. Weather indicators available:
   - Temperature
   - Humidity
   - Pressure
   - Wind
   - Precipitation
   - Visibility
   - UV Index

9. Dataset is suitable for:
   - Climate Profiling
   - Anomaly Detection
   - Rainfall Risk Prediction
   - Heatwave Risk Prediction
   - Climate Risk Scoring
   - Explainable AI
""")


# yyy
# Out:
# CLIMATE INSIGHTS REPORT
#
# 1. Dataset contains 119,398 environmental observations.
#
# 2. Dataset covers 552 unique locations across India.
#
# 3. Dataset includes 33 regions/states.
#
# 4. Dataset contains weather, air quality,
#    geographical, temporal, and astronomical data.
#
# 5. No missing values detected.
#
# 6. No duplicate records detected.
#
# 7. Air quality indicators available:
#    - PM2.5
#    - PM10
#    - Carbon Monoxide
#    - Ozone
#    - Nitrogen Dioxide
#    - Sulphur Dioxide
#
# 8. Weather indicators available:
#    - Temperature
#    - Humidity
#    - Pressure
#    - Wind
#    - Precipitation
#    - Visibility
#    - UV Index
#
# 9. Dataset is suitable for:
#    - Climate Profiling
#    - Anomaly Detection
#    - Rainfall Risk Prediction
#    - Heatwave Risk Prediction
#    - Climate Risk Scoring
#    - Explainable AI
